# %% [markdown]
# **Data Wrangling II**

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c1e336a8-32ba-4378-a626-82a8701e44b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1e336a8-32ba-4378-a626-82a8701e44b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Stuednt_Academic_Performance.csv")

# %%
df
# Out:
#     Roll No               Name      WT  DSBDA    CC     AI  Total  Percentage  \
# 0         1      Aakash Kanchan   56.0   68.0  48.0   60.0  232.0       58.00
# 1         2         Rohan Kadam   65.0   65.0  47.0    NaN  236.0       59.00
# 2         3        Kunal Jadhav   50.0    NaN  42.0   57.0  211.0       52.75
# 3         4      sarvesh Bomble   58.0   61.0  48.0   57.0  224.0       56.00
# 4         5       Mangesh Kadam    NaN   64.0  47.0   56.0  231.0         NaN
# 5         6        Mrunal Kadam   57.0   70.0   NaN   57.0    NaN       58.00
# 6         7       Aniket Jagtap   63.0   64.0  45.0   59.0  231.0       57.75
# 7         8       Tanaya Kamble  100.0   64.0  47.0   59.0  223.0       55.75
# 8         9       Atharv Jamdar   63.0   62.0 -30.0   55.0  500.0       56.00
# 9        10      Anurag Bhosale   66.0   60.0  50.0   57.0  233.0       58.25
# 10       11       Pratik Abnave    NaN   64.0  50.0   58.0  239.0       59.75
# ...

# %% [markdown]
# **Data Preprocessing**

# %%
df.head()
# Out:
#    Roll No           Name     WT  DSBDA    CC    AI  Total  Percentage Result
# 0        1  Aakash Kanchan  56.0   68.0  48.0  60.0  232.0       58.00   pass
# 1        2     Rohan Kadam  65.0   65.0  47.0   NaN  236.0       59.00   pass
# 2        3    Kunal Jadhav  50.0    NaN  42.0  57.0  211.0       52.75   fail
# 3        4  sarvesh Bomble  58.0   61.0  48.0  57.0  224.0       56.00    NaN
# 4        5   Mangesh Kadam   NaN   64.0  47.0  56.0  231.0         NaN   pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     30 non-null     int64
#  1   Name        30 non-null     object
#  2   WT          27 non-null     float64
#  3   DSBDA       27 non-null     float64
#  4   CC          27 non-null     float64
#  5   AI          27 non-null     float64
#  6   Total       27 non-null     float64
#  7   Percentage  27 non-null     float64
#  8   Result      27 non-null     object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 2.2+ KB

# %%
df.describe()
# Out:
#          Roll No          WT       DSBDA         CC          AI       Total  \
# count  30.000000   27.000000   27.000000  27.000000   27.000000   27.000000
# mean   15.500000   65.851852   67.629630  42.962963   64.370370  225.925926
# std     8.803408   28.454692   16.705937  14.851784   37.128828   83.904216
# min     1.000000   50.000000   60.000000 -30.000000   55.000000 -100.000000
# 25%     8.250000   55.000000   63.000000  43.000000   56.000000  223.500000
# 50%    15.500000   60.000000   64.000000  46.000000   57.000000  227.000000
# 75%    22.750000   64.500000   66.500000  48.000000   58.000000  233.000000
# max    30.000000  200.000000  150.000000  50.000000  250.000000  500.000000
#
#        Percentage
# count   27.000000
# mean    56.842593
# std      2.003780
# min     52.750000
# 25%     55.875000
# 50%     56.500000
# 75%     58.000000
# max     61.000000

# %%
df.describe(include="all")
# Out:
#           Roll No           Name           WT       DSBDA         CC  \
# count   30.000000              30   27.000000   27.000000  27.000000
# unique        NaN              30         NaN         NaN        NaN
# top           NaN  Aakash Kanchan         NaN         NaN        NaN
# freq          NaN               1         NaN         NaN        NaN
# mean    15.500000             NaN   65.851852   67.629630  42.962963
# std      8.803408             NaN   28.454692   16.705937  14.851784
# min      1.000000             NaN   50.000000   60.000000 -30.000000
# 25%      8.250000             NaN   55.000000   63.000000  43.000000
# 50%     15.500000             NaN   60.000000   64.000000  46.000000
# 75%     22.750000             NaN   64.500000   66.500000  48.000000
# max     30.000000             NaN  200.000000  150.000000  50.000000
#
#                 AI       Total  Percentage Result
# count    27.000000   27.000000   27.000000     27
# ...

# %%
df.shape
# Out:
# (30, 9)

# %%
df.dtypes
# Out:
# Roll No         int64
# Name           object
# WT            float64
# DSBDA         float64
# CC            float64
# AI            float64
# Total         float64
# Percentage    float64
# Result         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Roll No', 'Name ', 'WT', 'DSBDA', 'CC', 'AI', 'Total', 'Percentage',
#        'Result'],
#       dtype='object')

# %%
df[0:5]
# Out:
#    Roll No           Name     WT  DSBDA    CC    AI  Total  Percentage Result
# 0        1  Aakash Kanchan  56.0   68.0  48.0  60.0  232.0       58.00   pass
# 1        2     Rohan Kadam  65.0   65.0  47.0   NaN  236.0       59.00   pass
# 2        3    Kunal Jadhav  50.0    NaN  42.0  57.0  211.0       52.75   fail
# 3        4  sarvesh Bomble  58.0   61.0  48.0  57.0  224.0       56.00    NaN
# 4        5   Mangesh Kadam   NaN   64.0  47.0  56.0  231.0         NaN   pass

# %%
df.loc[0:2]
# Out:
#    Roll No           Name     WT  DSBDA    CC    AI  Total  Percentage Result
# 0        1  Aakash Kanchan  56.0   68.0  48.0  60.0  232.0       58.00   pass
# 1        2     Rohan Kadam  65.0   65.0  47.0   NaN  236.0       59.00   pass
# 2        3    Kunal Jadhav  50.0    NaN  42.0  57.0  211.0       52.75   fail

# %%
df.loc[0:2,'WT':'AI']
# Out:
#      WT  DSBDA    CC    AI
# 0  56.0   68.0  48.0  60.0
# 1  65.0   65.0  47.0   NaN
# 2  50.0    NaN  42.0  57.0

# %%
df.iloc[1:3]
# Out:
#    Roll No         Name     WT  DSBDA    CC    AI  Total  Percentage Result
# 1        2   Rohan Kadam  65.0   65.0  47.0   NaN  236.0       59.00   pass
# 2        3  Kunal Jadhav  50.0    NaN  42.0  57.0  211.0       52.75   fail

# %%
df.iloc[1:5,1:5]
# Out:
#             Name     WT  DSBDA    CC
# 1     Rohan Kadam  65.0   65.0  47.0
# 2    Kunal Jadhav  50.0    NaN  42.0
# 3  sarvesh Bomble  58.0   61.0  48.0
# 4   Mangesh Kadam   NaN   64.0  47.0

# %% [markdown]
# **Identification and Handling of Null Values**

# %%
df.isnull()
# Out:
#     Roll No  Name      WT  DSBDA     CC     AI  Total  Percentage  Result
# 0     False  False  False  False  False  False  False       False   False
# 1     False  False  False  False  False   True  False       False   False
# 2     False  False  False   True  False  False  False       False   False
# 3     False  False  False  False  False  False  False       False    True
# 4     False  False   True  False  False  False  False        True   False
# 5     False  False  False  False   True  False   True       False   False
# 6     False  False  False  False  False  False  False       False   False
# 7     False  False  False  False  False  False  False       False   False
# 8     False  False  False  False  False  False  False       False   False
# 9     False  False  False  False  False  False  False       False   False
# 10    False  False   True  False  False  False  False       False   False
# 11    False  False  False  False  False  False  False       False   False
# ...

# %%
df.isnull().any()
# Out:
# Roll No       False
# Name          False
# WT             True
# DSBDA          True
# CC             True
# AI             True
# Total          True
# Percentage     True
# Result         True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# WT            3
# DSBDA         3
# CC            3
# AI            3
# Total         3
# Percentage    3
# Result        3
# dtype: int64

# %%
df.WT.isnull().sum()
# Out:
# 3

# %% [markdown]
# **Make a list of column having missing value**

# %%
cols_with_na = []
for col in df.columns:
    if df[col].isna().any():
        cols_with_na.append(col)
cols_with_na
# Out:
# ['WT', 'DSBDA', 'CC', 'AI', 'Total', 'Percentage', 'Result']

# %% [markdown]
# **Filling missing values using dropna(), fillna(), replace() :**

# %% [markdown]
# **Replacing null values with NaN**

# %%
df.replace(np.nan,value=0)
# Out:
#     Roll No               Name      WT  DSBDA    CC     AI  Total  Percentage  \
# 0         1      Aakash Kanchan   56.0   68.0  48.0   60.0  232.0       58.00
# 1         2         Rohan Kadam   65.0   65.0  47.0    0.0  236.0       59.00
# 2         3        Kunal Jadhav   50.0    0.0  42.0   57.0  211.0       52.75
# 3         4      sarvesh Bomble   58.0   61.0  48.0   57.0  224.0       56.00
# 4         5       Mangesh Kadam    0.0   64.0  47.0   56.0  231.0        0.00
# 5         6        Mrunal Kadam   57.0   70.0   0.0   57.0    0.0       58.00
# 6         7       Aniket Jagtap   63.0   64.0  45.0   59.0  231.0       57.75
# 7         8       Tanaya Kamble  100.0   64.0  47.0   59.0  223.0       55.75
# 8         9       Atharv Jamdar   63.0   62.0 -30.0   55.0  500.0       56.00
# 9        10      Anurag Bhosale   66.0   60.0  50.0   57.0  233.0       58.25
# 10       11       Pratik Abnave    0.0   64.0  50.0   58.0  239.0       59.75
# ...

# %% [markdown]
#  **Filling null values with fillna()**

# %%
df.fillna(1)
# Out:
#     Roll No               Name      WT  DSBDA    CC     AI  Total  Percentage  \
# 0         1      Aakash Kanchan   56.0   68.0  48.0   60.0  232.0       58.00
# 1         2         Rohan Kadam   65.0   65.0  47.0    1.0  236.0       59.00
# 2         3        Kunal Jadhav   50.0    1.0  42.0   57.0  211.0       52.75
# 3         4      sarvesh Bomble   58.0   61.0  48.0   57.0  224.0       56.00
# 4         5       Mangesh Kadam    1.0   64.0  47.0   56.0  231.0        1.00
# 5         6        Mrunal Kadam   57.0   70.0   1.0   57.0    1.0       58.00
# 6         7       Aniket Jagtap   63.0   64.0  45.0   59.0  231.0       57.75
# 7         8       Tanaya Kamble  100.0   64.0  47.0   59.0  223.0       55.75
# 8         9       Atharv Jamdar   63.0   62.0 -30.0   55.0  500.0       56.00
# 9        10      Anurag Bhosale   66.0   60.0  50.0   57.0  233.0       58.25
# 10       11       Pratik Abnave    1.0   64.0  50.0   58.0  239.0       59.75
# ...

# %% [markdown]
# **Filling missing values using mean, median,max, min and standard deviation of that column**

# %%
df['CC']=df['CC'].fillna(df['CC'].mean())

# %%
df.head(10)
# Out:
#    Roll No           Name      WT  DSBDA         CC    AI  Total  Percentage  \
# 0        1  Aakash Kanchan   56.0   68.0  48.000000  60.0  232.0       58.00
# 1        2     Rohan Kadam   65.0   65.0  47.000000   NaN  236.0       59.00
# 2        3    Kunal Jadhav   50.0    NaN  42.000000  57.0  211.0       52.75
# 3        4  sarvesh Bomble   58.0   61.0  48.000000  57.0  224.0       56.00
# 4        5   Mangesh Kadam    NaN   64.0  47.000000  56.0  231.0         NaN
# 5        6    Mrunal Kadam   57.0   70.0  42.962963  57.0    NaN       58.00
# 6        7   Aniket Jagtap   63.0   64.0  45.000000  59.0  231.0       57.75
# 7        8   Tanaya Kamble  100.0   64.0  47.000000  59.0  223.0       55.75
# 8        9   Atharv Jamdar   63.0   62.0 -30.000000  55.0  500.0       56.00
# 9       10  Anurag Bhosale   66.0   60.0  50.000000  57.0  233.0       58.25
#
#   Result
# 0   pass
# 1   pass
# 2   fail
# 3    NaN
# 4   pass
# 5   pass
# 6   pass
# 7   pass
# 8   pass
# 9   pass

# %%
df['CC']=df['WT'].fillna(df['AI'].mean())

# %%
df.head(10)
# Out:
#    Roll No           Name      WT  DSBDA         CC    AI  Total  Percentage  \
# 0        1  Aakash Kanchan   56.0   68.0   56.00000  60.0  232.0       58.00
# 1        2     Rohan Kadam   65.0   65.0   65.00000   NaN  236.0       59.00
# 2        3    Kunal Jadhav   50.0    NaN   50.00000  57.0  211.0       52.75
# 3        4  sarvesh Bomble   58.0   61.0   58.00000  57.0  224.0       56.00
# 4        5   Mangesh Kadam    NaN   64.0   64.37037  56.0  231.0         NaN
# 5        6    Mrunal Kadam   57.0   70.0   57.00000  57.0    NaN       58.00
# 6        7   Aniket Jagtap   63.0   64.0   63.00000  59.0  231.0       57.75
# 7        8   Tanaya Kamble  100.0   64.0  100.00000  59.0  223.0       55.75
# 8        9   Atharv Jamdar   63.0   62.0   63.00000  55.0  500.0       56.00
# 9       10  Anurag Bhosale   66.0   60.0   66.00000  57.0  233.0       58.25
#
#   Result
# 0   pass
# 1   pass
# 2   fail
# 3    NaN
# 4   pass
# 5   pass
# 6   pass
# 7   pass
# 8   pass
# 9   pass

# %% [markdown]
# **Deleting null values using dropna() method**

# %%
df.dropna()
# Out:
#     Roll No               Name      WT  DSBDA     CC     AI  Total  \
# 0         1      Aakash Kanchan   56.0   68.0   56.0   60.0  232.0
# 6         7       Aniket Jagtap   63.0   64.0   63.0   59.0  231.0
# 7         8       Tanaya Kamble  100.0   64.0  100.0   59.0  223.0
# 8         9       Atharv Jamdar   63.0   62.0   63.0   55.0  500.0
# 9        10      Anurag Bhosale   66.0   60.0   66.0   57.0  233.0
# 11       12       Sejal Gadewar   61.0   68.0   61.0   55.0  226.0
# 12       13       Sayali Chavan   50.0   67.0   50.0   58.0  217.0
# 13       14       Harsh Khodake   54.0   64.0   54.0   57.0  224.0
# 16       17        Aditya Dayal   54.0   66.0   54.0   58.0  226.0
# 17       18     Suraj Chinchole   67.0   63.0   67.0   56.0  232.0
# 18       19  Akanksha Deshpande   53.0   60.0   53.0   56.0  212.0
# 19       20            Ram Mane   59.0   63.0   59.0   58.0  225.0
# 21       22        Rajat Shelar  200.0   66.0  200.0  250.0  244.0
# ...

# %%
df.dropna(how="all")
# Out:
#     Roll No               Name      WT  DSBDA         CC     AI  Total  \
# 0         1      Aakash Kanchan   56.0   68.0   56.00000   60.0  232.0
# 1         2         Rohan Kadam   65.0   65.0   65.00000    NaN  236.0
# 2         3        Kunal Jadhav   50.0    NaN   50.00000   57.0  211.0
# 3         4      sarvesh Bomble   58.0   61.0   58.00000   57.0  224.0
# 4         5       Mangesh Kadam    NaN   64.0   64.37037   56.0  231.0
# 5         6        Mrunal Kadam   57.0   70.0   57.00000   57.0    NaN
# 6         7       Aniket Jagtap   63.0   64.0   63.00000   59.0  231.0
# 7         8       Tanaya Kamble  100.0   64.0  100.00000   59.0  223.0
# 8         9       Atharv Jamdar   63.0   62.0   63.00000   55.0  500.0
# 9        10      Anurag Bhosale   66.0   60.0   66.00000   57.0  233.0
# 10       11       Pratik Abnave    NaN   64.0   64.37037   58.0  239.0
# 11       12       Sejal Gadewar   61.0   68.0   61.00000   55.0  226.0
# ...

# %%
df.dropna(axis=1)
# Out:
#     Roll No               Name          CC
# 0         1      Aakash Kanchan   56.00000
# 1         2         Rohan Kadam   65.00000
# 2         3        Kunal Jadhav   50.00000
# 3         4      sarvesh Bomble   58.00000
# 4         5       Mangesh Kadam   64.37037
# 5         6        Mrunal Kadam   57.00000
# 6         7       Aniket Jagtap   63.00000
# 7         8       Tanaya Kamble  100.00000
# 8         9       Atharv Jamdar   63.00000
# 9        10      Anurag Bhosale   66.00000
# 10       11       Pratik Abnave   64.37037
# 11       12       Sejal Gadewar   61.00000
# 12       13       Sayali Chavan   50.00000
# 13       14       Harsh Khodake   54.00000
# 14       15         Yash Dhumal   52.00000
# 15       16       Pranav Bodake   67.00000
# 16       17        Aditya Dayal   54.00000
# 17       18     Suraj Chinchole   67.00000
# 18       19  Akanksha Deshpande   53.00000
# 19       20            Ram Mane   59.00000
# 20       21       Shivam Shinde   56.00000
# ...

# %%
df.dropna(axis=0)
# Out:
#     Roll No               Name      WT  DSBDA     CC     AI  Total  \
# 0         1      Aakash Kanchan   56.0   68.0   56.0   60.0  232.0
# 6         7       Aniket Jagtap   63.0   64.0   63.0   59.0  231.0
# 7         8       Tanaya Kamble  100.0   64.0  100.0   59.0  223.0
# 8         9       Atharv Jamdar   63.0   62.0   63.0   55.0  500.0
# 9        10      Anurag Bhosale   66.0   60.0   66.0   57.0  233.0
# 11       12       Sejal Gadewar   61.0   68.0   61.0   55.0  226.0
# 12       13       Sayali Chavan   50.0   67.0   50.0   58.0  217.0
# 13       14       Harsh Khodake   54.0   64.0   54.0   57.0  224.0
# 16       17        Aditya Dayal   54.0   66.0   54.0   58.0  226.0
# 17       18     Suraj Chinchole   67.0   63.0   67.0   56.0  232.0
# 18       19  Akanksha Deshpande   53.0   60.0   53.0   56.0  212.0
# 19       20            Ram Mane   59.0   63.0   59.0   58.0  225.0
# 21       22        Rajat Shelar  200.0   66.0  200.0  250.0  244.0
# ...

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df
# Out:
#     Roll No               Name      WT  DSBDA     CC     AI  Total  \
# 0         1      Aakash Kanchan   56.0   68.0   56.0   60.0  232.0
# 6         7       Aniket Jagtap   63.0   64.0   63.0   59.0  231.0
# 7         8       Tanaya Kamble  100.0   64.0  100.0   59.0  223.0
# 8         9       Atharv Jamdar   63.0   62.0   63.0   55.0  500.0
# 9        10      Anurag Bhosale   66.0   60.0   66.0   57.0  233.0
# 11       12       Sejal Gadewar   61.0   68.0   61.0   55.0  226.0
# 12       13       Sayali Chavan   50.0   67.0   50.0   58.0  217.0
# 13       14       Harsh Khodake   54.0   64.0   54.0   57.0  224.0
# 16       17        Aditya Dayal   54.0   66.0   54.0   58.0  226.0
# 17       18     Suraj Chinchole   67.0   63.0   67.0   56.0  232.0
# 18       19  Akanksha Deshpande   53.0   60.0   53.0   56.0  212.0
# 19       20            Ram Mane   59.0   63.0   59.0   58.0  225.0
# 21       22        Rajat Shelar  200.0   66.0  200.0  250.0  244.0
# ...

# %% [markdown]
# **Identification and Handling of Outliers**

# %% [markdown]
# **Detecting Outliers**

# %% [markdown]
# **Detecting outliers using Boxplot**

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=df.WT)
# Out:
# <AxesSubplot:xlabel='WT'>

# %%
sns.boxplot(x=df.DSBDA)
# Out:
# <AxesSubplot:xlabel='DSBDA'>

# %%
sns.boxplot(x=df.AI)
# Out:
# <AxesSubplot:xlabel='AI'>

# %%
sns.boxplot(x=df.CC)
# Out:
# <AxesSubplot:xlabel='CC'>

# %%
sns.boxplot(x=df.Total)
# Out:
# <AxesSubplot:xlabel='Total'>

# %%
sns.boxplot(x=df.Percentage)
# Out:
# <AxesSubplot:xlabel='Percentage'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9, 6)
df_list = ['Roll No','WT','AI','DSBDA']
fig, axes = plt.subplots(2, 2)
fig.set_dpi(120)
count=0
for r in range(2):
 for c in range(2):
   _= df[df_list[count]].plot(kind = 'box', ax=axes[r,c])
   count+=1

# %% [markdown]
#  **Detect outlier using z-Score**

# %% [markdown]
# **Detecting outliers using Inter Quantile Range(IQR):**

# %%
Q1 = df['Percentage'].quantile(0.25)
Q3 = df['Percentage'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit}, Upper_limit = {Upper_limit}')
# Out:
# Q1 = 56.0, Q3 = 58.0, IQR = 2.0, Lower_limit = 53.0, Upper_limit = 61.0

# %%
df[(df['CC'] < Lower_limit) | (df['CC'] > Upper_limit)]
# Out:
#     Roll No            Name      WT  DSBDA     CC     AI  Total  Percentage  \
# 6         7    Aniket Jagtap   63.0   64.0   63.0   59.0  231.0       57.75
# 7         8    Tanaya Kamble  100.0   64.0  100.0   59.0  223.0       55.75
# 8         9    Atharv Jamdar   63.0   62.0   63.0   55.0  500.0       56.00
# 9        10   Anurag Bhosale   66.0   60.0   66.0   57.0  233.0       58.25
# 12       13    Sayali Chavan   50.0   67.0   50.0   58.0  217.0       54.25
# 17       18  Suraj Chinchole   67.0   63.0   67.0   56.0  232.0       58.00
# 21       22     Rajat Shelar  200.0   66.0  200.0  250.0  244.0       61.00
# 22       23     Amit Ghadage   62.0   70.0   62.0   57.0  235.0       58.75
# 28       29         Sai Mane   69.0   65.0   69.0   56.0  240.0       60.00
# 29       30       Ram Shinde   64.0   65.0   64.0   60.0  231.0       57.75
#
#    Result
# 6    pass
# 7    pass
# 8    pass
# 9    pass
# 12   fail
# 17   pass
# 21   pass
# 22   pass
# 28   pass
# 29   pass

# %% [markdown]
# **Handling of Outliers**

# %% [markdown]
# **Removing the outlier:**

# %%
outliers=[]
for i in df.CC:
    if i<Lower_limit or i>Upper_limit:
        outliers.append(i)
print("outliers are",outliers)
# Out:
# outliers are [63.0, 100.0, 63.0, 66.0, 50.0, 67.0, 200.0, 62.0, 69.0, 64.0]

# %%
Upper_limit
# Out:
# 61.0

# %%
Lower_limit
# Out:
# 53.0

# %%
df[df.CC<Lower_limit].index
# Out:
# Int64Index([12], dtype='int64')

# %%
df1=df.drop(df[df.CC<Lower_limit].index)

# %%
df1.shape
# Out:
# (17, 9)

# %%
df2=df[df.CC<Lower_limit]
df2
# Out:
#     Roll No          Name     WT  DSBDA    CC    AI  Total  Percentage Result
# 12       13  Sayali Chavan  50.0   67.0  50.0  58.0  217.0       54.25   fail

# %% [markdown]
# **Mean/Median imputation**

# %%
sns.kdeplot(df.CC)
# Out:
# <AxesSubplot:xlabel='CC', ylabel='Density'>

# %%
sns.kdeplot(df1.CC)
# Out:
# <AxesSubplot:xlabel='CC', ylabel='Density'>

# %%
df.Percentage
# Out:
# 0     58.00
# 6     57.75
# 7     55.75
# 8     56.00
# 9     58.25
# 11    56.50
# 12    54.25
# 13    56.00
# 16    56.50
# 17    58.00
# 18    53.00
# 19    56.25
# 21    61.00
# 22    58.75
# 24    56.75
# 25    55.25
# 28    60.00
# 29    57.75
# Name: Percentage, dtype: float64

# %%
df.CC
# Out:
# 0      56.0
# 6      63.0
# 7     100.0
# 8      63.0
# 9      66.0
# 11     61.0
# 12     50.0
# 13     54.0
# 16     54.0
# 17     67.0
# 18     53.0
# 19     59.0
# 21    200.0
# 22     62.0
# 24     60.0
# 25     61.0
# 28     69.0
# 29     64.0
# Name: CC, dtype: float64

# %%
log_percentage=np.log(df.Percentage)
log_percentage
# Out:
# 0     4.060443
# 6     4.056123
# 7     4.020877
# 8     4.025352
# 9     4.064744
# 11    4.034241
# 12    3.993603
# 13    4.025352
# 16    4.034241
# 17    4.060443
# 18    3.970292
# 19    4.029806
# 21    4.110874
# 22    4.073291
# 24    4.038656
# 25    4.011868
# 28    4.094345
# 29    4.056123
# Name: Percentage, dtype: float64

# %%
sns.kdeplot(log_percentage)
# Out:
# <AxesSubplot:xlabel='Percentage', ylabel='Density'>

# %% [markdown]
# **Data Transformation**

# %%
import seaborn as sns

# %% [markdown]
# **Checking the distribution with Skewness**

# %%
df.skew()
# Out:
# <ipython-input-127-9e0b1e29546f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Roll No      -0.095744
# WT            3.642108
# DSBDA        -0.079696
# CC            3.642108
# AI            4.233881
# Total         4.141039
# Percentage    0.081682
# dtype: float64

# %% [markdown]
# **Checking the distribution of variables using KDE plot**

# %%
sns.kdeplot(df.AI);

# %%
sns.kdeplot(df.WT);

# %%
sns.kdeplot(df.DSBDA);

# %%
sns.kdeplot(df.Percentage);
